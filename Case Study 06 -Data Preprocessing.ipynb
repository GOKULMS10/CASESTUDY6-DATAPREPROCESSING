# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Load the dataset into python environment.

# %%
df = pd.read_csv('Downloads/titanic_dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 2. Make ‘PassengerId’ as the index column

# %%
df = pd.read_csv('Downloads/titanic_dataset.csv', index_col='PassengerId')

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# # 3. Check the basic details of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# There are so many missing values present in the dataset.

# %% [markdown]
# # 4. Fill in all the missing values present in all the columns in the dataset

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# Filling the values in the feature age
plt.hist(df['Age'])
plt.show()

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# Since so many values are missing in the column cabin we can drop it.Dropping cabin will not affect the data.
df = df.drop('Cabin',axis=1)

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
# Filling the missing values in column Embarked
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# Now all the missing values has been filled.

# %% [markdown]
# # 5. Check and handle outliers in at least 3 columns in the dataset

# %%
# Checking oulier in the column age
plt.boxplot(df['Age'])
plt.show()

# %%
Q1 = np.percentile(df['Age'],25,interpolation='midpoint')
Q2 = np.percentile(df['Age'],50,interpolation='midpoint')
Q3 = np.percentile(df['Age'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 22.0
# 29.69911764705882
# 35.0

# %%
IQR = Q3-Q1
low_lim = Q1 - 1.5*IQR
up_lim = Q3 + 1.5*IQR
print(low_lim)
print(up_lim)
# Out:
# 2.5
# 54.5

# %%
outlier = []
for x in df['Age']:
    if( (x<low_lim) or (x>up_lim) ):
        outlier.append(x)

# %%
outlier
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
ind1=df['Age']>up_lim
df.loc[ind1].index
# Out:
# Int64Index([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
#             269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
#             556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
#             830, 852, 880],
#            dtype='int64', name='PassengerId')

# %%
ind1=df['Age']<low_lim
df.loc[ind1].index
# Out:
# Int64Index([  8,  17,  79, 120, 165, 173, 184, 206, 298, 306, 341, 382, 387,
#             470, 480, 531, 643, 645, 756, 789, 804, 825, 828, 832],
#            dtype='int64', name='PassengerId')

# %%
df.drop([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
            269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
            556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
            830, 852, 880, 8,  17,  79, 120, 165, 173, 184, 206, 298, 306, 341, 382, 387,
            470, 480, 531, 643, 645, 756, 789, 804, 825, 828, 832],inplace=True)

# %%
plt.boxplot(df['Age'])
plt.show()

# %%
# Checking outlier in SibSp
plt.boxplot(df['SibSp'])
plt.show()

# %%
Q1 = np.percentile(df['SibSp'],25,interpolation='midpoint')
Q2 = np.percentile(df['SibSp'],50,interpolation='midpoint')
Q3 = np.percentile(df['SibSp'],75,interpolation='midpoint')
IQR = Q3-Q1
low_lim = Q1 - 1.5*IQR
up_lim = Q3 + 1.5*IQR
print(low_lim)
print(up_lim)
# Out:
# -1.5
# 2.5

# %%
outlier = []
for x in df['SibSp']:
    if( (x<low_lim) or (x>up_lim) ):
        outlier.append(x)

# %%
outlier
# Out:
# [3,
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  3,
#  8,
#  4,
#  3,
#  8,
#  4,
#  8,
#  3,
#  4,
#  4,
#  4,
#  4,
#  8,
#  3,
#  3,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  5,
#  4,
#  3,
#  4,
#  8,
#  4,
#  3,
#  8,
#  4,
#  8]

# %%
ind1=df['SibSp']>up_lim
df.loc[ind1].index
# Out:
# Int64Index([ 25,  28,  51,  60,  64,  69,  72,  86,  89, 160, 172, 177, 181,
#             183, 202, 230, 234, 262, 267, 279, 325, 342, 375, 410, 481, 486,
#             542, 543, 635, 684, 687, 727, 788, 793, 814, 820, 847, 851, 864],
#            dtype='int64', name='PassengerId')

# %%
df.drop([ 25,  28,  51,  60,  64,  69,  72,  86,  89, 160, 172, 177, 181,
            183, 202, 230, 234, 262, 267, 279, 325, 342, 375, 410, 481, 486,
            542, 543, 635, 684, 687, 727, 788, 793, 814, 820, 847, 851, 864],inplace=True)

# %%
plt.boxplot(df['SibSp'])
plt.show()

# %%
# Checking the outlier in Fare
plt.boxplot(df['Fare'])
plt.show()

# %%
Q1 = np.percentile(df['Fare'],25,interpolation='midpoint')
Q2 = np.percentile(df['Fare'],50,interpolation='midpoint')
Q3 = np.percentile(df['Fare'],75,interpolation='midpoint')
IQR = Q3-Q1
low_lim = Q1 - 1.5*IQR
up_lim = Q3 + 1.5*IQR
print(low_lim)
print(up_lim)
# Out:
# -21.885499999999997
# 57.5313

# %%
outlier = []
for x in df['Fare']:
    if( (x<low_lim) or (x>up_lim) ):
        outlier.append(x)

# %%
outlier
# Out:
# [71.2833,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  61.175,
#  63.3583,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  61.3792,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  135.6333,
#  78.85,
#  91.0792,
#  247.5208,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  135.6333,
#  57.9792,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  59.4,
#  93.5,
#  57.9792,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  78.2667,
#  153.4625,
#  65.0,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
#  211.3375,
#  110.8833,
#  227.525,
#  151.55,
#  227.525,
#  211.3375,
#  512.3292,
# ...

# %%
ind1=df['Fare']>up_lim
df.loc[ind1].index.values
# Out:
# array([  2,  32,  35,  53,  62,  63,  73,  93,  98, 103, 119, 121, 125,
#        140, 152, 156, 216, 219, 225, 231, 246, 257, 258, 259, 263, 270,
#        291, 292, 300, 307, 308, 311, 312, 319, 320, 326, 330, 333, 335,
#        337, 338, 370, 374, 376, 378, 381, 386, 391, 394, 413, 436, 446,
#        454, 485, 487, 497, 499, 505, 506, 514, 521, 524, 528, 538, 541,
#        545, 551, 558, 559, 582, 586, 592, 610, 616, 628, 642, 646, 656,
#        661, 666, 680, 682, 690, 699, 701, 709, 717, 731, 738, 742, 743,
#        755, 760, 764, 766, 780, 790, 803, 821, 836, 850, 857], dtype=int64)

# %%
df.drop([2,  32,  35,  53,  62,  63,  73,  93,  98, 103, 119, 121, 125,
       140, 152, 156, 216, 219, 225, 231, 246, 257, 258, 259, 263, 270,
       291, 292, 300, 307, 308, 311, 312, 319, 320, 326, 330, 333, 335,
       337, 338, 370, 374, 376, 378, 381, 386, 391, 394, 413, 436, 446,
       454, 485, 487, 497, 499, 505, 506, 514, 521, 524, 528, 538, 541,
       545, 551, 558, 559, 582, 586, 592, 610, 616, 628, 642, 646, 656,
       661, 666, 680, 682, 690, 699, 701, 709, 717, 731, 738, 742, 743,
       755, 760, 764, 766, 780, 790, 803, 821, 836, 850, 857],inplace = True)

# %%
plt.boxplot(df['Fare'])
plt.show()

# %% [markdown]
# # 6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
df.head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
#
#                 Sex        Age  SibSp  Parch            Ticket     Fare  \
# PassengerId
# 1              male  22.000000      1      0         A/5 21171   7.2500
# 3            female  26.000000      0      0  STON/O2. 3101282   7.9250
# 4            female  35.000000      1      0            113803  53.1000
# 5              male  35.000000      0      0            373450   8.0500
# 6              male  29.699118      0      0            330877   8.4583
#
#             Embarked
# PassengerId
# ...

# %%
df.Ticket.nunique()
# Out:
# 592

# %% [markdown]
# Since columns Name and Ticket have so many unique values they are not contributing towards our calculation and do not have a direct impact on survival.

# %%
df = df.drop('Name',axis = 1)

# %%
df = df.drop('Ticket',axis = 1)

# %%
df.head()
# Out:
#              Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# PassengerId
# 1                   0       3    male  22.000000      1      0   7.2500
# 3                   1       3  female  26.000000      0      0   7.9250
# 4                   1       1  female  35.000000      1      0  53.1000
# 5                   0       3    male  35.000000      0      0   8.0500
# 6                   0       3    male  29.699118      0      0   8.4583
#
#             Embarked
# PassengerId
# 1                  S
# 3                  S
# 4                  S
# 5                  S
# 6                  Q

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#              Survived  Pclass        Age  SibSp  Parch     Fare  Sex_female  \
# PassengerId
# 1                   0       3  22.000000      1      0   7.2500           0
# 3                   1       3  26.000000      0      0   7.9250           1
# 4                   1       1  35.000000      1      0  53.1000           1
# 5                   0       3  35.000000      0      0   8.0500           0
# 6                   0       3  29.699118      0      0   8.4583           0
#
#              Sex_male  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 1                   1           0           0           1
# 3                   0           0           0           1
# 4                   0           0           0           1
# 5                   1           0           0           1
# 6                   1           0           1           0

# %%
x = df.drop('Survived' , axis=1)
y = df['Survived']

# %%
x.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare  Sex_female  \
# count  684.000000  684.000000  684.000000  684.000000  684.000000  684.000000
# mean     2.504386   29.005059    0.271930    0.267544   16.317275    0.309942
# std      0.714816    9.440358    0.500982    0.755690   12.611508    0.462808
# min      1.000000    3.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   23.000000    0.000000    0.000000    7.854200    0.000000
# 50%      3.000000   29.699118    0.000000    0.000000   10.500000    0.000000
# 75%      3.000000   33.000000    0.000000    0.000000   23.062500    1.000000
# max      3.000000   54.000000    2.000000    6.000000   57.000000    1.000000
#
#          Sex_male  Embarked_C  Embarked_Q  Embarked_S
# count  684.000000  684.000000  684.000000  684.000000
# mean     0.690058    0.146199    0.099415    0.754386
# std      0.462808    0.353564    0.299438    0.430766
# ...

# %%
from sklearn import preprocessing 
min_max = preprocessing.MinMaxScaler(feature_range=(0,1))
x = min_max.fit_transform(x)

# %%
x = pd.DataFrame(x)

# %%
x.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  684.000000  684.000000  684.000000  684.000000  684.000000  684.000000
# mean     0.752193    0.509903    0.135965    0.044591    0.286268    0.309942
# std      0.357408    0.185105    0.250491    0.125948    0.221255    0.462808
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.392157    0.000000    0.000000    0.137793    0.000000
# 50%      1.000000    0.523512    0.000000    0.000000    0.184211    0.000000
# 75%      1.000000    0.588235    0.000000    0.000000    0.404605    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7           8           9
# count  684.000000  684.000000  684.000000  684.000000
# mean     0.690058    0.146199    0.099415    0.754386
# std      0.462808    0.353564    0.299438    0.430766
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2)
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit (x_train, y_train)
predict = model.predict(x_test)
from sklearn.metrics import mean_squared_error
print('MSE is :',mean_squared_error(y_test,predict))
from sklearn.metrics import r2_score
print('r2 score is:',r2_score(y_test,predict))
# Out:
# MSE is : 0.1327269616788321
# r2 score is: 0.40488477215719054

# %% [markdown]
# Since MSE is 0.13 and r2 score is 0.40 we can say that this is  a good predictive model.
